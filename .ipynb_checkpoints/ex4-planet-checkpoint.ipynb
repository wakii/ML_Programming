# %% [markdown]
# <a href="https://colab.research.google.com/github/wakii/ML_Programming/blob/master/ex4-planet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Multi-label prediction with Planet Amazon dataset

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/ex4'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from fastai.vision import *

# %% [markdown]
# ## Getting the data

# %% [markdown]
# The planet dataset isn't available on the [fastai dataset page](https://course.fast.ai/datasets) due to copyright restrictions. You can download it from Kaggle however. Let's see how to do this by using the [Kaggle API](https://github.com/Kaggle/kaggle-api) as it's going to be pretty useful to you if you want to join a competition or use other Kaggle datasets later on.
#
# First, install the Kaggle API by uncommenting the following line and executing it, or by executing it in your terminal (depending on your platform you may need to modify this slightly to either add `source activate fastai` or similar, or prefix `pip` with a path. Have a look at how `conda install` is called for your platform in the appropriate *Returning to work* section of https://course.fast.ai/. (Depending on your environment, you may also need to append "--user" to the command.)

# %%
! {sys.executable} -m pip install kaggle --upgrade
# Out:
# Requirement already up-to-date: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# ...

# %% [markdown]
# Then you need to upload your credentials from Kaggle on your instance. Login to kaggle and click on your profile picture on the top left corner, then 'My account'. Scroll down until you find a button named 'Create New API Token' and click on it. This will trigger the download of a file named 'kaggle.json'.
#
# Upload this file to the directory this notebook is running in, by clicking "Upload" on your main Jupyter page, then uncomment and execute the next two commands (or run them in a terminal). For Windows, uncomment the last two commands.

# %%
pwd
# Out:
# '/content'

# %%
! mkdir -p ~/.kaggle/
! mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# For Windows, uncomment these two commands
# ! mkdir %userprofile%\.kaggle
# ! move kaggle.json %userprofile%\.kaggle

# %% [markdown]
# > ## kaggle api를 현재 이용할수 없다.
# - 따라서 colab에 mount한 gdrive에 직접 다운로드한 파일을 업로드 한 후 이를 이동시켰다.

# %% [markdown]
# You're all set to download the data from [planet competition](https://www.kaggle.com/c/planet-understanding-the-amazon-from-space). You **first need to go to its main page and accept its rules**, and run the two cells below (uncomment the shell commands to download and unzip the data). If you get a `403 forbidden` error it means you haven't accepted the competition rules yet (you have to go to the competition page, click on *Rules* tab, and then scroll to the bottom to find the *accept* button).

# %%
path = Config.data_path()/'planet'
path.mkdir(parents=True, exist_ok=True)
path
# Out:
# PosixPath('/root/.fastai/data/planet')

# %%
ls

# %%
! kaggle competitions download -c planet-understanding-the-amazon-from-space -f train-jpg.tar.7z -p {path}  
# !mv '{base_dir}/train_v2.csv' {path}
# !mv '{base_dir}/train-jpg.tar.7z' {path}
! kaggle competitions download -c planet-understanding-the-amazon-from-space -f train_v2.csv -p {path}  
! unzip -q -n {path}/train_v2.csv -d {path}
# Out:
# 404 - Not Found
# 404 - Not Found
# [/root/.fastai/data/planet/train_v2.csv]
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /root/.fastai/data/planet/train_v2.csv or
#         /root/.fastai/data/planet/train_v2.csv.zip, and cannot find /root/.fastai/data/planet/train_v2.csv.ZIP, period.

# %%
! unzip -q -n {path}/train_v2.csv -d {path}
# Out:
# unzip:  cannot find or open /root/.fastai/data/planet/train_v2.csv, /root/.fastai/data/planet/train_v2.csv.zip or /root/.fastai/data/planet/train_v2.csv.ZIP.

# %% [markdown]
# To extract the content of this file, we'll need 7zip, so uncomment the following line if you need to install it (or run `sudo apt install p7zip-full` in your terminal).

# %%
# ! conda install --yes --prefix {sys.prefix} -c haasad eidl7zip

# %%
# !sudo apt install p7zip-full
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-6).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %% [markdown]
# - 이미 planet에 올려놨기에 comment 처리

# %% [markdown]
# And now we can unpack the data (uncomment to run - this might take a few minutes to complete).

# %%
! 7za -bd -y -so x {path}/train-jpg.tar.7z | tar xf - -C {path.as_posix()}

# %% [markdown]
# ## Multiclassification

# %% [markdown]
# Contrary to the pets dataset studied in last lesson, here each picture can have multiple labels. If we take a look at the csv file containing the labels (in 'train_v2.csv' here) we see that each 'image_name' is associated to several tags separated by spaces.

# %%
df = pd.read_csv(path/'train_v2.csv')
df.head()
# Out:
#   image_name                                       tags
# 0    train_0                               haze primary
# 1    train_1            agriculture clear primary water
# 2    train_2                              clear primary
# 3    train_3                              clear primary
# 4    train_4  agriculture clear habitation primary road

# %% [markdown]
# To put this in a `DataBunch` while using the [data block API](https://docs.fast.ai/data_block.html), we then need to using `ImageList` (and not `ImageDataBunch`). This will make sure the model created has the proper loss function to deal with the multiple classes.

# %% [markdown]
# - lesson check : ImageList vs ImageDataBunch

# %%
tfms = get_transforms(flip_vert=True, max_lighting=0.1, max_zoom=1.05, max_warp=0.)

# %% [markdown]
# - 사진 변경
#   - 뒤집기
#   - 빛, 대조 변화
#   - 줌
#   - warp 변화
#     - 촬영 위치에 따른 보이는 것 변화(?)

# %% [markdown]
# We use parentheses around the data block pipeline below, so that we can use a multiline statement without needing to add '\\'.

# %%
np.random.seed(42)
src = (ImageList.from_csv(path, 'train_v2.csv', folder='train-jpg', suffix='.jpg')
       .split_by_rand_pct(0.2)
       .label_from_df(label_delim=' '))

# %% [markdown]
# - code for returning images and labels

# %% [markdown]
# - dataset을 만들어 주는 코드

# %%
data = (src.transform(tfms, size=128)
        .databunch().normalize(imagenet_stats))

# %% [markdown]
# - databunch() : dataloader와 pyTorch databunch로 한번에 만들어준다.

# %% [markdown]
# - multiple classes를 다루는 databunch를 만드는 과정

# %% [markdown]
# - ImageList에서 data를 가져와 위에서 설정한 tranformation 적용하여 하나의 databunch로 만든 후, 이를 imagenet 데이터로 normalize 한다.

# %% [markdown]
# - pyTorch의 기본 class Dataset이 그 subclasses들로 imageClassification 등을 가진다.
# - gradient descent를 적용하기 위해서는 minibatch로 병렬처리를 해야 하며, minibatch를 만들기 위해 pytorch의 class인 Dataloader를 이용한다.
#   - dataset을 받아서, batch size로 구분된 single or mutiple-process iterator로 만들어준다.
# - validation set을 만들기 위해 databunch로 만들어준다.
#
# - dataset -> dataloader -> databunch -> learner

# %% [markdown]
# [data block API documentation](https://docs.fast.ai/data_block.html#Step-1:-Provide-inputs)

# %%
doc(DataBunch)
# Out:
# <h2 id="DataBunch" class="doc_header"><code>class</code> <code>DataBunch</code><a href="https://github.com/fastai/fastai/blob/master/fastai/basic_data.py#L84" class="source_link" style="float:right">[source]</a><a class="source_link" data-toggle="collapse" data-target="#DataBunch-pytest" style="float:right; padding-right:10px">[test]</a></h2><blockquote><p><code>DataBunch</code>(<strong><code>train_dl</code></strong>:<a href="https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader"><code>DataLoader</code></a>, <strong><code>valid_dl</code></strong>:<a href="https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader"><code>DataLoader</code></a>, <strong><code>fix_dl</code></strong>:<a href="https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader"><code>DataLoader</code></a>=<strong><em><code>None</code></em></strong>, <strong><code>test_dl</code></strong>:<code>Optional</code>[<a href="https://pytorch.org/docs/stable/data.html#torch.utils.data.Da
# ...

# %% [markdown]
# -

# %% [markdown]
# `show_batch` still works, and show us the different labels separated by `;`.

# %%
data.show_batch(rows=3, figsize=(12,9))

# %% [markdown]
# To create a `Learner` we use the same function as in lesson 1. Our base architecture is resnet50 again, but the metrics are a little bit differeent: we use `accuracy_thresh` instead of `accuracy`. In lesson 1, we determined the predicition for a given class by picking the final activation that was the biggest, but here, each activation can be 0. or 1. `accuracy_thresh` selects the ones that are above a certain threshold (0.5 by default) and compares them to the ground truth.
#
# As for Fbeta, it's the metric that was used by Kaggle on this competition. See [here](https://en.wikipedia.org/wiki/F1_score) for more details.

# %%
data.c
# Out:
# 17

# %%
arch = models.resnet50

# %% [markdown]
# - 사용할 architecture(model) 지정

# %%
acc_02 = partial(accuracy_thresh, thresh=0.2)
f_score = partial(fbeta, thresh=0.2)
learn = cnn_learner(data, arch, metrics=[acc_02, f_score])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# ...

# %% [markdown]
# - 이전 lesson1, 2에는 가장 probability 가 높은 class로 prediction했었다.
#   - 그 class의 index 를 argmax라 한다.
# - 여기서는 한 data가 가질 수 있는 label들이 여러개가 될 수 있기에, 해당 label로 판정짓는 기준을 threshold로 잡으며 이를 0.2로 설정하였다.
# - matrics : model이 train 하는 것에 영향을 주지 않는다. training 상태 등 train을 어떻기 진행하는지를 표시 하기 위해 이용
# - f_score : kaggle이 제공하는 채점 기준(fbeta)

# %%
partial??

# %% [markdown]
# - partial : 함수와, 그 함수에 들어가는 하나의 인자를 인자로 받아 새로운 함수를 리턴해준다.
#   - 정의하고 그것을 사용할 필요 없이 lambda처럼 바로 사용 가능
#   - `accuracy_thresh` 함수를 인자로 받아, 원래 그 함수의 인자로 쓰는 thresh를 설정한 함수를 리턴한다.

# %%
accuracy??

# %% [markdown]
# We use the LR Finder to pick a good learning rate.

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ...

# %%
learn.recorder.plot()

# %% [markdown]
# Then we can fit the head of our network.

# %%
lr = 0.01

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.134195</td>
#       <td>0.117004</td>
#       <td>0.946169</td>
#       <td>0.899248</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.115631</td>
#       <td>0.100981</td>
#       <td>0.947992</td>
#       <td>0.910871</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.102586</td>
#       <td>0.094589</td>
#       <td>0.954707</td>
#       <td>0.918345</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.094698</td>
#       <td>0.089042</td>
#       <td>0.955891</td>
#       <td>0.921378</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.save('stage-1-rn50')

# %% [markdown]
# ...And fine-tune the whole model:

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ...

# %%
learn.fit_one_cycle(5, slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.099196</td>
#       <td>0.091930</td>
#       <td>0.955622</td>
#       <td>0.920952</td>
#       <td>02:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.095187</td>
#       <td>0.090934</td>
#       <td>0.950979</td>
#       <td>0.919349</td>
#       <td>02:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.090979</td>
#       <td>0.085912</td>
#       <td>0.956574</td>
#       <td>0.925546</td>
#       <td>02:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.083726</td>
#       <td>0.082958</td>
#       <td>0.958108</td>
#       <td>0.928049</td>
#       <td>02:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.save('stage-2-rn50')

# %%
data = (src.transform(tfms, size=256)
        .databunch().normalize(imagenet_stats))

learn.data = data
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 256, 256])

# %%
learn.freeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ...

# %%
lr=1e-2/2

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.087560</td>
#       <td>0.085267</td>
#       <td>0.957664</td>
#       <td>0.924886</td>
#       <td>04:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.084320</td>
#       <td>0.084807</td>
#       <td>0.958020</td>
#       <td>0.925358</td>
#       <td>04:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.085839</td>
#       <td>0.083675</td>
#       <td>0.957882</td>
#       <td>0.926969</td>
#       <td>04:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.080674</td>
#       <td>0.081350</td>
#       <td>0.960993</td>
#       <td>0.930021</td>
#       <td>04:18</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
learn.save('stage-1-256-rn50')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(5, slice(1e-5, lr/5))
# Out:
# Total time: 11:25 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy_thresh</th>
#     <th>fbeta</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.082938</th>
#     <th>0.083548</th>
#     <th>0.957846</th>
#     <th>0.927756</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.086312</th>
#     <th>0.084802</th>
#     <th>0.958718</th>
#     <th>0.925416</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.084824</th>
#     <th>0.082339</th>
#     <th>0.959975</th>
#     <th>0.930054</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.078784</th>
#     <th>0.081425</th>
#     <th>0.959983</th>
#     <th>0.929634</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.074530</th>
#     <th>0.080791</th>
#     <th>0.960426</th>
#     <th>0.931257</th>
#   </tr>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-2-256-rn50')

# %% [markdown]
# You won't really know how you're going until you submit to Kaggle, since the leaderboard isn't using the same subset as we have for training. But as a guide, 50th place (out of 938 teams) on the private leaderboard was a score of `0.930`.

# %%
learn.export()

# %% [markdown]
# ## fin

# %% [markdown]
# (This section will be covered in part 2 - please don't ask about it just yet! :) )

# %%
#! kaggle competitions download -c planet-understanding-the-amazon-from-space -f test-jpg.tar.7z -p {path}  
#! 7za -bd -y -so x {path}/test-jpg.tar.7z | tar xf - -C {path}
#! kaggle competitions download -c planet-understanding-the-amazon-from-space -f test-jpg-additional.tar.7z -p {path}  
#! 7za -bd -y -so x {path}/test-jpg-additional.tar.7z | tar xf - -C {path}

# %%
test = ImageList.from_folder(path/'test-jpg').add(ImageList.from_folder(path/'test-jpg-additional'))
len(test)
# Out:
# 61191

# %%
learn = load_learner(path, test=test)
preds, _ = learn.get_preds(ds_type=DatasetType.Test)

# %%
thresh = 0.2
labelled_preds = [' '.join([learn.data.classes[i] for i,p in enumerate(pred) if p > thresh]) for pred in preds]

# %%
labelled_preds[:5]
# Out:
# ['agriculture cultivation partly_cloudy primary road',
#  'clear haze primary water',
#  'agriculture clear cultivation primary',
#  'clear primary',
#  'partly_cloudy primary']

# %%
fnames = [f.name[:-4] for f in learn.data.test_ds.items]

# %%
df = pd.DataFrame({'image_name':fnames, 'tags':labelled_preds}, columns=['image_name', 'tags'])

# %%
df.to_csv(path/'submission.csv', index=False)

# %%
! kaggle competitions submit planet-understanding-the-amazon-from-space -f {path/'submission.csv'} -m "My submission"
# Out:
# ...
# 100%|██████████████████████████████████████| 2.18M/2.18M [00:02<00:00, 1.05MB/s]
# Successfully submitted to Planet: Understanding the Amazon from Space

# %% [markdown]
# Private Leaderboard score: 0.9296 (around 80th)
